# %% [markdown]
# Nested Aggregation with Struct Arrays
#
# data = [
#     ("alice", "carrot", 1),
#     ("bob", "banana", 3),
#     ("alice", "tomato", 4),
#     ("bob", "carrot", 2),
#     ("charlie", "banana", 5),
#     ("bob", "apple", 1),
#     ("alice", "tomato", 2),
#     ("charlie", "carrot", 3)
# ]
#
#
# The final result is conceptually:
# alice    [{carrot,1}, {tomato,6}]  - 7
# bob      [{banana,3}, {carrot,2}, {apple,1}] - 6
# charlie  [{banana,5}, {carrot,3}]  - 8

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql import types as T
from datetime import datetime
import sys
import os
import glob
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from pyspark.sql import SparkSession
#       2 from pyspark.sql import functions as F
#       3 from pyspark.sql import types as T
#       4 from datetime import datetime
#
# ModuleNotFoundError: No module named 'pyspark'

# %%
data = [
    ("alice", "carrot", 1),
    ("bob", "banana", 3),
    ("alice", "tomato", 4),
    ("bob", "carrot", 2),
    ("charlie", "banana", 5),
    ("bob", "apple", 1),
    ("alice", "tomato", 2),
    ("charlie", "carrot", 3)
]

# %%
spark = SparkSession.builder\
    .appName("Nested Aggregation Example")\
    .master("local[*]")\
    .getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 spark = SparkSession.builder\
#       2     .appName("Nested Aggregation Example")\
#       3     .master("local[*]")\
# ----> 4     .getOrCreate()
#
# File ~/venvs/global_env/lib/python3.14/site-packages/pyspark/sql/session.py:559, in SparkSession.Builder.getOrCreate(self)
#     557     sparkConf.set(key, value)
#     558 # This SparkContext may be an existing one.
# --> 559 sc = SparkContext.getOrCreate(sparkConf)
#     560 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     561 # by all sessions.
#     562 session = SparkSession(sc, options=self._options)
#
# File ~/venvs/global_env/lib/python3.14/site-packages/pyspark/core/context.py:542, in SparkContext.getOrCreate(cls, conf)
#     540 with SparkContext._lock:
#     541     if SparkContext._active_spark_context is None:
# ...
